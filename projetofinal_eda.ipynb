# %% [markdown]
# <a href="https://colab.research.google.com/github/biamuniz/trabalhofinal_eda_mjda/blob/main/projetofinal_eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
microdados = pd.read_csv(r'microdados.csv', sep=';')

# %%
microdados.head()

# %%
# Pivoted microdados_csv into df2
unused_columns = microdados.columns.difference(set(['medalha']).union(set(['sexo'])).union(set({'medalha'})))
tmp_df = microdados.drop(unused_columns, axis=1)
pivot_table = tmp_df.pivot_table(
    index=['medalha'],
    columns=['sexo'],
    values=['medalha'],
    aggfunc={'medalha': ['count']}
)

df2 = pivot_table.reset_index()

# %%
df2
# Out:
#        medalha
#                 count
# sexo                F       M
# 0       Bronze   3771    9524
# 1         Gold   3747    9622
# 2     No_medal  63125  166821
# 3       Silver   3735    9373

# %%
# Pivoted microdados_csv into df3
unused_columns = microdados.columns.difference(set(['idade']).union(set(['esporte'])).union(set({'idade'})))
tmp_df = microdados.drop(unused_columns, axis=1)
pivot_table = tmp_df.pivot_table(
    index=['idade'],
    columns=['esporte'],
    values=['idade'],
    aggfunc={'idade': ['count']}
)

# Reset the column name and the indexes
df3 = pivot_table.reset_index()

# %%
df3
# Out:
#         idade                            ...
#                     count                ...
# esporte       Aeronautics Alpine Skiing  ... Water Polo Weightlifting Wrestling
# 0        10.0         NaN           NaN  ...        NaN           NaN       NaN
# 1        11.0         NaN           NaN  ...        NaN           NaN       NaN
# 2        12.0         NaN           NaN  ...        NaN           NaN       NaN
# 3        13.0         NaN           NaN  ...        NaN           NaN       NaN
# 4        14.0         NaN          12.0  ...        1.0           NaN       NaN
# ..        ...         ...           ...  ...        ...           ...       ...
# 69       81.0         NaN           NaN  ...        NaN           NaN       NaN
# 70       84.0         NaN           NaN  ...        NaN           NaN       NaN
# 71       88.0         NaN           NaN  ...        NaN           NaN       NaN
# 72       96.0         NaN           NaN  ...        NaN           NaN       NaN
# ...

# %%
# Pivoted microdados_csv into df4
unused_columns = microdados.columns.difference(set(['esporte']).union(set([])).union(set({'idade'})))
tmp_df = microdados.drop(unused_columns, axis=1)
pivot_table = tmp_df.pivot_table(
    index=['esporte'],
    values=['idade'],
    aggfunc={'idade': ['mean', 'median']}
)

# Reset the column name and the indexes
df4 = pivot_table.reset_index()

# %%
df4
# Out:
#              esporte      idade
#                            mean median
# 0        Aeronautics  26.000000   26.0
# 1      Alpine Skiing  22.847759   23.0
# 2           Alpinism  38.812500   38.0
# 3            Archery  28.552663   26.0
# 4   Art Competitions  44.719596   44.0
# ..               ...        ...    ...
# 61        Tug-Of-War  29.309524   29.0
# 62        Volleyball  24.866691   25.0
# 63        Water Polo  25.479470   25.0
# 64     Weightlifting  25.671661   25.0
# 65         Wrestling  25.745950   25.0
#
# [66 rows x 3 columns]

# %%
# Import plotly and create a figure
import plotly.graph_objects as go
fig = go.Figure()


# Add the histogram traces to the figure

# %%
for column_header in ['idade']:
    fig.add_trace(go.Histogram(x=microdados[column_header], name=column_header))

# %%
fig.update_layout(
	xaxis_title='idade',
    title='idade frequencies',
    barmode='group'
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e8c8258d-02f2-45ad-b0e3-52491e89d1df" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e8c8258d-02f2-45ad-b0e3-52491e89d1df")) {
#                     Plotly.newPlot(
#                         'e8c8258d-02f2-45ad-b0e3-52491e89d1df',
# ...
